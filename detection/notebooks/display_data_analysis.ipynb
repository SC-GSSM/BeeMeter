# %%
from detection.dataset.data_analysis import Analyser
from detection.dataset.dataset_generator import Dataset
# Out:
# Faster NMS is used!

# %%
base_dir = "/home/t9s9/PycharmProjects/BeeMeter/data/training/"
dataset = Dataset.from_sqlite(images_dirs=base_dir + "base_training_img", path=base_dir + "base_labels.db",
                              verbose=False) + \
          Dataset.from_sqlite(images_dirs=base_dir + "gopro_training_img",
                              path=base_dir + "gopro_labels.db", verbose=False)

a = Analyser((400, 200), dataset)
# Out:
# /home/t9s9/PycharmProjects/BeeMeter/detection/dataset/dataset_generator.py:269: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return cls(np.array(filenames), np.array(image_ids), np.array(labels), nr_labels=nr_labels,

# %%
a.scales()
# Out:
# (15160, 2)

# %%
a.ratio_join()
# Out:
# /home/t9s9/anaconda3/envs/tensorflow_2/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
a.box_distribution('join')
# Out:
# /home/t9s9/anaconda3/envs/tensorflow_2/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
a.ratio_euclid_means(c=3, show=True, tries=3)
# Out:
# Groups: 3: 100%|██████████| 3/3 [00:01<00:00,  2.58it/s]
# Accuracy: 77.00%
# Boxes:
#  [[10.945934   19.67055755]
#  [14.55793842 15.00102447]
#  [10.40513925  9.07915767]]
# Ratios:
#  [0.56, 0.97, 1.15]
# {'groups': 3,
#  'dist': 'euclid',
#  'accuracy': 0.7699960671397645,
#  'rations': array([0.55646282, 0.97046295, 1.14604676])}

# %%
a.ratio_iou_means(c=3, show=True, tries=3)
# Out:
# Groups: 3: 100%|██████████| 3/3 [00:12<00:00,  4.32s/it]
# Accuracy: 77.57%
# Boxes:
#  [[13.75       17.87234043]
#  [10.         18.72340426]
#  [10.625       9.36170213]]
# Boxes norm:
#  [[0.05729167 0.07446809]
#  [0.04166667 0.07801418]
#  [0.04427083 0.03900709]]
# Ratios:
#  [0.534, 0.769, 1.135]
# {'groups': 3,
#  'dist': 'median',
#  'accuracy': 0.7756667208893734,
#  'rations': [0.534, 0.769, 1.135]}
